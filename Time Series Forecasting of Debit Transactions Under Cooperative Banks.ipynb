# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline 
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, pacf

# %%
#Reading the data file from github
data=pd.read_csv('https://raw.githubusercontent.com/imtiazBDSgit/PythonScripts/master/NEFT_RBI.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data.head()
# Out:
#           TYPE                      BANK  DEBITS_TRANSACTIONS  DEBIT_AMOUNT  \
# 0  COOPERATIVE  ABHYUDAYA CO-OP BANK LTD                37408       2149.64
# 1  COOPERATIVE  ABHYUDAYA CO-OP BANK LTD                37810       2418.89
# 2  COOPERATIVE  ABHYUDAYA CO-OP BANK LTD                38030       2309.36
# 3  COOPERATIVE  ABHYUDAYA CO-OP BANK LTD                40801       2313.26
# 4  COOPERATIVE  ABHYUDAYA CO-OP BANK LTD                39431       2233.91
#
#    CREDIT_TRANSACTIONS  CREDIT_AMOUNT       DATE
# 0                97422        3470.74 2016-05-01
# 1               101211        3619.33 2016-06-01
# 2               104050        3618.13 2016-07-01
# 3               110826        3789.99 2016-08-01
# 4               107036        3650.23 2016-09-01

# %% [markdown]
# ### Considering only Cooperative Banks and aggregating over the years transaction

# %%
data_Cooperative=data[data['TYPE']=='COOPERATIVE']
data_Cooperative=data_Cooperative.set_index('DATE')
data_Cooperative=data_Cooperative.drop(['BANK'])
data_Cooperative=data_Cooperative.groupby(data_Cooperative.index).sum()
data_Cooperative=data_Cooperative.reset_index()
data_Cooperative=data_Cooperative.set_index('DATE')

# %% [markdown]
# ### Cooperative BANK DEBIT TRANSACTIONS

# %%
ts = data_Cooperative['DEBITS_TRANSACTIONS']
fig =plt.figure()
plt.plot(ts)
fig.suptitle('Time Series Plot of CREDIT TRANSACTIONS', fontsize=20)
plt.xlabel('Month - Year')
plt.ylabel('DEBIT CARD TRANSACTIONS COUNT')

# %% [markdown]
# ### plotting the moving average quarterly

# %%
ts_log = np.log(ts)
plt.plot(ts_log)
moving_avg = pd.rolling_mean(ts_log,4)
plt.plot(ts_log)
plt.plot(moving_avg, color='red')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=4,center=False).mean()
#   app.launch_new_instance()

# %% [markdown]
# ### Smoothing to apply forecasting model

# %%
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %% [markdown]
# ### Dropping the NA values from preventing calculation errors

# %%
ts_log_diff.dropna(inplace=True)

# %% [markdown]
# ### Calculating ACF and PACF Values

# %%
lag_acf = acf(ts_log_diff, nlags=4)
lag_pacf = pacf(ts_log_diff, nlags=4, method='ols')

# %% [markdown]
# ### Plot ACF and PACF

# %%
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# ##### The graph cuts the upper confidence levels at less than 1 so lets take p and q values to be 1 for Arima Modelling

# %% [markdown]
# ### Arima Modelling

# %%
model = ARIMA(ts_log, order=(1, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff)**2))

# %% [markdown]
# ### Converting the predictions back to normal scale

# %%
predictions_ARIMA_diff = pd.Series(results_AR.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
predictions_ARIMA_log = pd.Series(ts_log.ix[0], index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# DATE
# 2016-06-01    0.060833
# 2016-07-01    0.060788
# 2016-08-01    0.061154
# 2016-09-01    0.060854
# 2016-10-01    0.061378
# dtype: float64
# DATE
# 2016-06-01    0.060833
# 2016-07-01    0.121621
# 2016-08-01    0.182775
# 2016-09-01    0.243629
# 2016-10-01    0.305007
# dtype: float64
# DATE
# 2016-05-01    13.601588
# 2016-06-01    13.662421
# 2016-07-01    13.723209
# 2016-08-01    13.784363
# 2016-09-01    13.845217
# dtype: float64

# %% [markdown]
# ### Plotting the Arima Model curve with the exact values.

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
